# %%
import numpy as np 
import pandas as pd

# %%
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/abc/titanic_train.csv")
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.barplot(data=data,x="Sex",y='PassengerId',hue="Survived")

# %%
f=sns.load_dataset("flights")
f.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
sns.relplot(data=f,x='year',y="passengers")

# %%
sns.barplot(data=f,x=f.year,y=f.passengers,ci="sd",estimator=np.median)

# %%
sns.kdeplot(f.year)

# %%
sns.kdeplot(f.passengers)

# %%
sns.relplot(data=f,x=f.month,y=f.passengers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-53b3380ea61d> in <module>
# ----> 1 sns.relplot(data=f,x=f.month,y=f.passengers)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1693
#    1694     # Draw the plot
# -> 1695     g.map_dataframe(func, x, y,
#    1696                     hue=hue, size=size, style=style,
#    1697                     **plot_kws)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     829
#     830         # Finalize the annotations and layout
# --> 831         self._finalize_grid(args[:2])
#     832
# ...

# %%
sns.barplot(data=data,x=data.Sex,y=data.Survived)
sns.set(style="darkgrid",palette="deep",font_scale=5)

# %%
sns.get_dataset_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
p=sns.load_dataset("planets")
p
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.relplot(data=f,x='passengers',y='month',hue='year')
sns.set(font_scale=1)

# %%
sns.relplot(data=f,x='passengers',y='month')

# %%
#sns.kdeplot(data,shade=True,label="titanic")
#sns.kdeplot(f,shade=True,label="fligth")
sns.kdeplot(p,shade=True,label="planet")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-43c8dc9d5252> in <module>
#       1 #sns.kdeplot(data,shade=True,label="titanic")
#       2 #sns.kdeplot(f,shade=True,label="fligth")
# ----> 3 sns.kdeplot(p,shade=True,label="planet")
#       4 plt.legend()
#       5 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     662         return ax
#     663
# --> 664     data = data.astype(np.float64)
#     665     if data2 is not None:
#     666         if isinstance(data2, list):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# ...

# %%
sns.kdeplot(data.Age)

# %%
sns.kdeplot(data.Survived)

# %%
sns.boxplot(data=data,x=data.Age,y=data.Sex)

# %%
sns.boxenplot(data=data,x=data.Sex,y=data.Age)

# %%
sns.violinplot(data=data,x="Sex",y="Age",hue="Survived")

# %%
sns.stripplot(data=data,x=data.Age,y=data.Sex,hue="Survived")

# %%
sns.stripplot(data=data)
